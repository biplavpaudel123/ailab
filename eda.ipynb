# %% [markdown]
# <a href="https://colab.research.google.com/github/biplavpaudel123/ailab/blob/main/eda.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Import necessary libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# Load the dataset into a pandas DataFrame
# Load dataset
def load_dataset(file_path):
  return pd.read_csv(file_path)


df = load_dataset("/content/drive/MyDrive/Hello data/nepal-earthquake-severity-index-latest.csv")
df.head(5)
# Out:
#          P_CODE            VDC_NAME   DISTRICT   REGION  Hazard (Intensity)  \
# 0  C-BAG-27-031       KathmanduN.P.  Kathmandu  Central                2.17
# 1  C-BAG-25-027        LalitpurN.P.   Lalitpur  Central                1.72
# 2  C-NAR-35-005      BharatpurN. P.   Chitawan  Central                2.21
# 3  C-BAG-26-012  MadhyapurThimiN.P.  Bhaktapur  Central                2.45
# 4  C-BAG-27-028             Jorpati  Kathmandu  Central                1.91
#
#    Exposure  Housing  Poverty  Vulnerability  Severity  Severity Normalized  \
# 0     10.00     8.86     1.82           5.34      4.88              10.0000
# 1      2.26     8.40     0.82           4.61      2.62               5.3707
# 2      1.47     5.38     2.53           3.96      2.34               4.8083
# 3      0.85     8.23     0.89           4.56      2.12               4.3447
# 4      0.87     8.86     1.82           5.34      2.07               4.2407
#
#   Severity category
# 0           Highest
# ...

# %%
# Categorical data
# countplot
sns.countplot(data=df, x='REGION')
df['Severity category'].value_counts()
# Out:
# Lowest         1893
# Low             800
# Medium-Low      672
# Medium-High     433
# High            168
# Highest          19
# Name: Severity category, dtype: int64

# %%
 # pie chart

df['REGION'].value_counts().plot(kind='pie',autopct='%0.2f')
# Out:
# <Axes: ylabel='REGION'>

# %%
# Numberical Value

# Histogram treat as categorical data distribution of data

plt.hist(df['Vulnerability'])
# Out:
# (array([ 91.,  83., 189., 491., 717., 696., 726., 598., 208., 186.]),
#  array([1.62 , 2.341, 3.062, 3.783, 4.504, 5.225, 5.946, 6.667, 7.388,
#         8.109, 8.83 ]),
#  <BarContainer object of 10 artists>)

# %%
# Distplot
# probability density function --> The line is kde
# skweness
sns.distplot(df['Vulnerability'])
# Out:
# <ipython-input-19-9f8d8bbba313>:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Vulnerability'])
# <Axes: xlabel='Vulnerability', ylabel='Density'>

# %%
# Boxplot
# 5 number summary
# median , percentile, min=Q1-1.5*IQR, max=Q3+1.5*IQR, IQR = (Q1-Q3), outlier

sns.boxplot(df['Vulnerability'])
# Out:
# <Axes: ylabel='Vulnerability'>

# %%
df.describe()
# Out:
#        Hazard (Intensity)     Exposure      Housing      Poverty  \
# count         3985.000000  3985.000000  3985.000000  3985.000000
# mean             0.320537     0.067493     5.706522     5.481854
# std              0.779937     0.187551     1.953037     2.270975
# min              0.000000     0.000000     1.170000     0.000000
# 25%              0.000000     0.030000     4.640000     3.330000
# 50%              0.010000     0.050000     5.610000     5.620000
# 75%              0.130000     0.070000     6.850000     7.350000
# max             10.000000    10.000000     9.940000    10.000000
#
#        Vulnerability     Severity  Severity Normalized
# count    3985.000000  3985.000000          3985.000000
# mean        5.594635     0.248720             0.510221
# std         1.450817     0.298756             0.612652
# min         1.620000     0.000000             0.000000
# 25%         4.590000     0.050000             0.094100
# ...

# %%
# Visualize the distribution of numerical variables
plt.figure(figsize=(10, 6))
sns.histplot(data['Hazard (Intensity)'], kde=True, bins=20)
plt.title('Distribution of Hazard (Intensity)')
plt.xlabel('Hazard (Intensity)')
plt.ylabel('Frequency')
plt.show()

plt.figure(figsize=(10, 6))
sns.boxplot(x='REGION', y='Exposure', data=data)
plt.title('Boxplot of Exposure by Region')
plt.xlabel('Region')
plt.ylabel('Exposure')
plt.show()

# %%
# Visualize the relationship between variables
plt.figure(figsize=(10, 6))
sns.scatterplot(x='Severity', y='Severity Normalized', data=data, hue='Severity category')
plt.title('Scatter plot of Severity vs. Severity Normalized')
plt.xlabel('Severity')
plt.ylabel('Severity Normalized')
plt.legend(title='Severity category')
plt.show()
